# %%
[1]AI:
>Smart application that can perform its own task without any human intervention
>EX:Self driving cars

ML:
>Subset of AI
>Provide stats tool to learn,analyze,visualize and develop predictive models from data
>Ex:Recommendation in amazon,flipkart

DL:
>Subset of ML
>Mimic human mind
>Multi layered human network
>Ex:Object detectin,Image recognition,Chatbot,chatgpt

[2]SUPERVISED ML:
>Train data on a given  model and then use them to predict the output
>Two types:Classification(Pass/Fail predictions in ana examination) and Regression problem(Predicting Price of house)
>Dataset has a specific output

[3]UNSUPERVISED ML:
>Form clusters of dataset
>Ex:Customer segmentation:When we launch a prod,use clusters to target audience

[4]AI:
>Smart application that can perform its own task without any human intervention
>EX:Self driving cars

ML:
>Subset of AI
>Provide stats tool to learn,analyze,visualize and develop predictive models from data
>Ex:Recommendation in amazon,flipkart

DL:
>Subset of ML
>Mimic human mind
>Multi layered human network
>Ex:Object detectin,Image recognition,Chatbot,chatgpt

DS:
>Union of all 3
>Linear algebra,Stats,probability,calculus

[5]SUPERVISED ML:
>Train data on a given  model and then use them to predict the output
>Two types:Classification(Pass/Fail) and Regression problem(Price of house)
>Dataset has a specific output

UNSUPERVISED ML:
>Form clusters of dataset
>Ex:Customer segmentation:When we launch a prod,use clusters to target audience

SEMI-SUPERVISED:
>Supervisd+Unsupervised
>Ex:Recommendatons for netflix:Apply cluster to find which region a show is then predict 
>Train model with supervised dataset and made into clusters

[6]DATASET:3 Types:
[1]Training dataset:Used to train the model(Books-Q and A-Train us with it)
[2]Validation dataset:Used to do hyper parameter tuning(tune with parametrs to inc                        accuracy)-(Guide books)
[3]Test dataset:Used to Test the model with unseen data to see how it works with                     accuracy(Exam paper test our skills)

>MODEL:Mathematical algorithm with equations that will do some predictions
>Model will never know about test data
>Ex:Exam 
>Model shudn't know what is there in test data

[7]When forming clusters if there exists certain sections of data that cannot be put in any clusters,we identify them to be anomalies.

[8]Supervised ML:Naive byes,SVM,Random forests
Unsupervised ML:KNN,Nueral Networks
